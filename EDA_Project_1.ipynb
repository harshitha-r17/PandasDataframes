# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/total_cars.txt")
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         state   city  year  make  \
# 0                0             0           0     CapitalUT  Delhi  2020  FORD
# 1                1             1           1     CapitalUT  Delhi  2016  Ford
# 2                2             2           2     CapitalUT  Delhi  2018  FORD
# 3                3             3           3     CapitalUT  Delhi  2019  FORD
# 4                4             4           4     CapitalUT  Delhi  2015  Ford
# ...            ...           ...         ...           ...    ...   ...   ...
# 1810           304             5           5  UttarPradesh  Noida  2021  Tata
# 1811           305             6           6  UttarPradesh  Noida  2018  Tata
# 1812           306             7           7  UttarPradesh  Noida  2022  Tata
# 1813           307             8           8  UttarPradesh  Noida  2018  Tata
# 1814           308             9           9  UttarPradesh  Noida  2019  Tata
#
# ...

# %%
#How many rows and columns are in the dataset?
df.shape
# Out:
# (1815, 17)

# %%
#What are the data types of each column?
df.dtypes
# Out:
# Unnamed: 0.2     int64
# Unnamed: 0.1     int64
# Unnamed: 0       int64
# state           object
# city            object
# year             int64
# make            object
# model           object
# series          object
# transmission    object
# fuel            object
# owner           object
# emi              int64
# kilometers       int64
# mileage          int64
# seating          int64
# price            int64
# dtype: object

# %%
#Are there any missing values in the dataset? If yes, in which columns?
df.isnull().any()
# Out:
# Unnamed: 0.2    False
# Unnamed: 0.1    False
# Unnamed: 0      False
# state           False
# city            False
# year            False
# make            False
# model           False
# series           True
# transmission     True
# fuel            False
# owner           False
# emi             False
# kilometers      False
# mileage         False
# seating         False
# price           False
# dtype: bool

# %%
#What are the minimum, maximum, mean, and median values of numerical columns (price, kilometers, mileage, emi)?

# %%
df1=df.select_dtypes(include=['number'])
df1
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  year    emi  kilometers  \
# 0                0             0           0  2020  15425       96075
# 1                1             1           1  2016  10792       55017
# 2                2             2           2  2018  13978       24931
# 3                3             3           3  2019  15503       22270
# 4                4             4           4  2015  10440       78906
# ...            ...           ...         ...   ...    ...         ...
# 1810           304             5           5  2021  12512       21726
# 1811           305             6           6  2018  10459       27451
# 1812           306             7           7  2022  14799       30399
# 1813           307             8           8  2018   9736       12249
# 1814           308             9           9  2019  10498       39417
#
#       mileage  seating   price
# 0           9        5  789000
# 1           9        5  552000
# ...

# %%
maximum=df1.max(axis=0)
maximum
# Out:
# Unnamed: 0.2        334
# Unnamed: 0.1         19
# Unnamed: 0           19
# year               2022
# emi               35765
# kilometers       100245
# mileage              19
# seating               7
# price           1879000
# dtype: int64

# %%
minn=df1.min(axis=0)
minn
# Out:
# Unnamed: 0.2         0
# Unnamed: 0.1         0
# Unnamed: 0           0
# year              2010
# emi               3715
# kilometers           1
# mileage              9
# seating              5
# price           190000
# dtype: int64

# %%
me=df1.mean(axis=0)
me
# Out:
# Unnamed: 0.2       136.200551
# Unnamed: 0.1         7.746556
# Unnamed: 0           7.746556
# year              2018.233609
# emi              13388.598347
# kilometers       37982.656198
# mileage             14.132782
# seating              5.071625
# price           692071.184573
# dtype: float64

# %%
med=df1.median(axis=0)
med
# Out:
# Unnamed: 0.2       121.0
# Unnamed: 0.1         7.0
# Unnamed: 0           7.0
# year              2019.0
# emi              11515.0
# kilometers       32282.0
# mileage             15.0
# seating              5.0
# price           589000.0
# dtype: float64

# %%
#What are the unique values and their counts for categorical columns (state, city, make, model, fuel, transmission, owner)?

# %%
df2=df.select_dtypes(include=['object'])
df2
# Out:
#              state   city  make     model                   series  \
# 0        CapitalUT  Delhi  FORD  ECOSPORT     TITANIUM 1.5L DIESEL
# 1        CapitalUT  Delhi  Ford  Ecosport       1.5AMBIENTE TI VCT
# 2        CapitalUT  Delhi  FORD  ECOSPORT     AMBIENTE 1.5L DIESEL
# 3        CapitalUT  Delhi  FORD  ECOSPORT     TITANIUM 1.5L PETROL
# 4        CapitalUT  Delhi  Ford  Ecosport  TITANIUM 1.5L PETROL AT
# ...            ...    ...   ...       ...                      ...
# 1810  UttarPradesh  Noida  Tata     Tiago                XZ PETROL
# 1811  UttarPradesh  Noida  Tata     Tiago         XZA 1.2 REVOTRON
# 1812  UttarPradesh  Noida  Tata     Tiago          XZ+ CNG 1.2 RTN
# 1813  UttarPradesh  Noida  Tata     Tiago          XZ 1.2 REVOTRON
# 1814  UttarPradesh  Noida  Tata     Tiago         XZA 1.2 REVOTRON
#
#      transmission    fuel owner
# 0          Manual  Diesel  1st
# 1          Manual  Petrol  1st
# 2          Manual  Diesel  1st
# 3          Manual  Petrol  1st
# ...

# %%
pd.unique(df2[['state', 'city','make','model','series','transmission','fuel','owner']].values.ravel())
# Out:
# array(['CapitalUT', 'Delhi', 'FORD', 'ECOSPORT', 'TITANIUM 1.5L DIESEL',
#        'Manual', 'Diesel', '1st ', 'Ford', 'Ecosport',
#        '1.5AMBIENTE TI VCT', 'Petrol', 'AMBIENTE 1.5L DIESEL',
#        'TITANIUM 1.5L PETROL', 'TITANIUM 1.5L PETROL AT', 'Automatic',
#        '2nd ', '1.5 TITANIUM TI VCT', '1.5TITANIUM TDCI',
#        '1.0 TREND+ (ECOBOOST)', 'TREND 1.5L PETROL',
#        '1.5 TITANIUM SIGNATURE TI VCT (SUNROOF)', 'CNG',
#        '1.5 TITANIUM TI VCT AT', 'FREESTYLE', 'FLAIR EDITION 1.2 TI VCT',
#        'TREND+ 1.2 TI-VCT', 'Honda', 'Amaze', '1.2 EMT I VTEC',
#        '1.2 S(O) MT PRIVILEGE EDITION', 'AMAZE', '1.2L I-VTEC E', 'HONDA',
#        '1.5 VXMT I DTEC', '1.2L I-VTEC EX', '1.2 EXMT I VTEC',
#        '1.2 V MT I-VTEC', '1.2 SX MT I VTEC', '1.2L I-VTEC SX',
#        '1.2L I-VTEC S', '1.5 SMT I DTEC', 'VX AT I DTEC', 'City', 'V AT',
#        'CITY', 'SV CVT PETROL', 'SV MT PETROL', 'V MT PETROL',
#        '1.5L I-VTEC VX (O) MT', 'ZX CVT', 'VX (O) PETROL',
# ...

# %%
df2.apply(pd.Series.value_counts)
# Out:
#                             state  city  make  model  series  transmission  \
#  New Wagon-R                  NaN   NaN   NaN  112.0     NaN           NaN
#  RXT (O) AMT 1.0 DUAL TONE    NaN   NaN   NaN    NaN     4.0           NaN
# 1.0                           NaN   NaN   NaN    NaN    19.0           NaN
# 1.0 CLIMBER OPT AMT           NaN   NaN   NaN    NaN     1.0           NaN
# 1.0 ECOBOOST TITANIUM         NaN   NaN   NaN    NaN     2.0           NaN
# ...                           ...   ...   ...    ...     ...           ...
# ZETA                          NaN   NaN   NaN    NaN    32.0           NaN
# ZX CVT                        NaN   NaN   NaN    NaN     9.0           NaN
# ZXI                           NaN   NaN   NaN    NaN    24.0           NaN
# ahmedabad                     NaN   3.0   NaN    NaN     NaN           NaN
# magna 1.2 crdi                NaN   NaN   NaN    NaN     1.0           NaN
#
#                             fuel  owner
# ...

# %%
#Which columns have missing values, and what percentage of the data is missing?

# %%
df.isna().any()
# Out:
# Unnamed: 0.2    False
# Unnamed: 0.1    False
# Unnamed: 0      False
# state           False
# city            False
# year            False
# make            False
# model           False
# series           True
# transmission     True
# fuel            False
# owner           False
# emi             False
# kilometers      False
# mileage         False
# seating         False
# price           False
# dtype: bool

# %%
df.isna().mean().mean()*100
# Out:
# 0.10371090584994327

# %%
#Suggest and apply appropriate strategies to handle missing values (e.g., imputation, dropping).

# %%
#Dropping Rows or Columns with Missing Values
a= df.dropna()
a
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         state   city  year  make  \
# 0                0             0           0     CapitalUT  Delhi  2020  FORD
# 1                1             1           1     CapitalUT  Delhi  2016  Ford
# 2                2             2           2     CapitalUT  Delhi  2018  FORD
# 3                3             3           3     CapitalUT  Delhi  2019  FORD
# 4                4             4           4     CapitalUT  Delhi  2015  Ford
# ...            ...           ...         ...           ...    ...   ...   ...
# 1810           304             5           5  UttarPradesh  Noida  2021  Tata
# 1811           305             6           6  UttarPradesh  Noida  2018  Tata
# 1812           306             7           7  UttarPradesh  Noida  2022  Tata
# 1813           307             8           8  UttarPradesh  Noida  2018  Tata
# 1814           308             9           9  UttarPradesh  Noida  2019  Tata
#
# ...

# %%
b= df.dropna(axis=1)
b
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         state   city  year  make  \
# 0                0             0           0     CapitalUT  Delhi  2020  FORD
# 1                1             1           1     CapitalUT  Delhi  2016  Ford
# 2                2             2           2     CapitalUT  Delhi  2018  FORD
# 3                3             3           3     CapitalUT  Delhi  2019  FORD
# 4                4             4           4     CapitalUT  Delhi  2015  Ford
# ...            ...           ...         ...           ...    ...   ...   ...
# 1810           304             5           5  UttarPradesh  Noida  2021  Tata
# 1811           305             6           6  UttarPradesh  Noida  2018  Tata
# 1812           306             7           7  UttarPradesh  Noida  2022  Tata
# 1813           307             8           8  UttarPradesh  Noida  2018  Tata
# 1814           308             9           9  UttarPradesh  Noida  2019  Tata
#
# ...

# %%
#Imputation of Missing Values
#Numerical Data
d = df1.copy()
d = d.fillna(d.mean())
d
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  year    emi  kilometers  \
# 0                0             0           0  2020  15425       96075
# 1                1             1           1  2016  10792       55017
# 2                2             2           2  2018  13978       24931
# 3                3             3           3  2019  15503       22270
# 4                4             4           4  2015  10440       78906
# ...            ...           ...         ...   ...    ...         ...
# 1810           304             5           5  2021  12512       21726
# 1811           305             6           6  2018  10459       27451
# 1812           306             7           7  2022  14799       30399
# 1813           307             8           8  2018   9736       12249
# 1814           308             9           9  2019  10498       39417
#
#       mileage  seating   price
# 0           9        5  789000
# 1           9        5  552000
# ...

# %%
#Categorical data
e = df2.copy()
e= e.fillna(e.mode())
e
# Out:
#              state   city  make     model                   series  \
# 0        CapitalUT  Delhi  FORD  ECOSPORT     TITANIUM 1.5L DIESEL
# 1        CapitalUT  Delhi  Ford  Ecosport       1.5AMBIENTE TI VCT
# 2        CapitalUT  Delhi  FORD  ECOSPORT     AMBIENTE 1.5L DIESEL
# 3        CapitalUT  Delhi  FORD  ECOSPORT     TITANIUM 1.5L PETROL
# 4        CapitalUT  Delhi  Ford  Ecosport  TITANIUM 1.5L PETROL AT
# ...            ...    ...   ...       ...                      ...
# 1810  UttarPradesh  Noida  Tata     Tiago                XZ PETROL
# 1811  UttarPradesh  Noida  Tata     Tiago         XZA 1.2 REVOTRON
# 1812  UttarPradesh  Noida  Tata     Tiago          XZ+ CNG 1.2 RTN
# 1813  UttarPradesh  Noida  Tata     Tiago          XZ 1.2 REVOTRON
# 1814  UttarPradesh  Noida  Tata     Tiago         XZA 1.2 REVOTRON
#
#      transmission    fuel owner
# 0          Manual  Diesel  1st
# 1          Manual  Petrol  1st
# 2          Manual  Diesel  1st
# 3          Manual  Petrol  1st
# ...

# %%
#Forward Fill or Backward Fill
f= df.copy()
f = f.ffill()
f
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         state   city  year  make  \
# 0                0             0           0     CapitalUT  Delhi  2020  FORD
# 1                1             1           1     CapitalUT  Delhi  2016  Ford
# 2                2             2           2     CapitalUT  Delhi  2018  FORD
# 3                3             3           3     CapitalUT  Delhi  2019  FORD
# 4                4             4           4     CapitalUT  Delhi  2015  Ford
# ...            ...           ...         ...           ...    ...   ...   ...
# 1810           304             5           5  UttarPradesh  Noida  2021  Tata
# 1811           305             6           6  UttarPradesh  Noida  2018  Tata
# 1812           306             7           7  UttarPradesh  Noida  2022  Tata
# 1813           307             8           8  UttarPradesh  Noida  2018  Tata
# 1814           308             9           9  UttarPradesh  Noida  2019  Tata
#
# ...

# %%
g= df.copy()
g = g.bfill()
g
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         state   city  year  make  \
# 0                0             0           0     CapitalUT  Delhi  2020  FORD
# 1                1             1           1     CapitalUT  Delhi  2016  Ford
# 2                2             2           2     CapitalUT  Delhi  2018  FORD
# 3                3             3           3     CapitalUT  Delhi  2019  FORD
# 4                4             4           4     CapitalUT  Delhi  2015  Ford
# ...            ...           ...         ...           ...    ...   ...   ...
# 1810           304             5           5  UttarPradesh  Noida  2021  Tata
# 1811           305             6           6  UttarPradesh  Noida  2018  Tata
# 1812           306             7           7  UttarPradesh  Noida  2022  Tata
# 1813           307             8           8  UttarPradesh  Noida  2018  Tata
# 1814           308             9           9  UttarPradesh  Noida  2019  Tata
#
# ...

# %%
#Plot the distribution of the price, kilometers, and mileage columns.

# %%
sns.histplot(df['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['kilometers'], kde=True)
# Out:
# <Axes: xlabel='kilometers', ylabel='Count'>

# %%
sns.histplot(df['mileage'], kde=True)
# Out:
# <Axes: xlabel='mileage', ylabel='Count'>

# %%
skewness = df[['price', 'kilometers', 'mileage']].skew()
skewness
# Out:
# price         1.559722
# kilometers    0.630941
# mileage      -0.241403
# dtype: float64

# %%
df3=df[['make', 'model']].head(5)
df3
# Out:
#    make     model
# 0  FORD  ECOSPORT
# 1  Ford  Ecosport
# 2  FORD  ECOSPORT
# 3  FORD  ECOSPORT
# 4  Ford  Ecosport

# %%
# Out:
# 0    FORD  ECOSPORT
# 1    Ford  Ecosport
# 2    FORD  ECOSPORT
# 3    FORD  ECOSPORT
# 4    Ford  Ecosport
# dtype: object

# %%
#Visualize the frequency distribution of the fuel, transmission, and owner columns.
sns.countplot(x='fuel', data=df)
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
sns.countplot(x='transmission', data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(x='owner', data=df)
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %%
#What is the relationship between price and kilometers? Use scatter plots and calculate the correlation coefficient.

# %%
sns.scatterplot(x='kilometers', y='price', data=df)
# Out:
# <Axes: xlabel='kilometers', ylabel='price'>

# %%
df['price'].corr(df['kilometers']) #As the number of kilometers increases, the price decreases
# Out:
# -0.4213071508614419

# %%
#Does higher mileage indicate lower prices? Analyze the relationship between mileage and price.

# %%
sns.scatterplot(x='mileage', y='price', data=df)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
df['price'].corr(df['mileage']) #As the mileage increases, the price decreases
# Out:
# -0.3195211371594323

# %%
# Compare the average price of cars based on their fuel type.

# %%
z= df.groupby('fuel')['price'].mean().reset_index()
z
# Out:
#      fuel          price
# 0     CNG  574147.368421
# 1  Diesel  973565.445026
# 2  Petrol  670202.370990

# %%
sns.barplot(x='fuel', y='price', data=z)
# Out:
# <Axes: xlabel='fuel', ylabel='price'>

# %%
# How does the transmission type affect the average price?

# %%
h=df.groupby('transmission')['price'].mean().reset_index()
h
# Out:
#                                transmission          price
# 0                     1.0 TREND+ (ECOBOOST)  638000.000000
# 1   1.5 TITANIUM SIGNATURE TI VCT (SUNROOF)  935000.000000
# 2                       1.5 TITANIUM TI VCT  719750.000000
# 3                    1.5 TITANIUM TI VCT AT  555666.666667
# 4                        1.5AMBIENTE TI VCT  552000.000000
# 5                          1.5TITANIUM TDCI  738250.000000
# 6                      AMBIENTE 1.5L DIESEL  715000.000000
# 7                                 Automatic  876702.535211
# 8                  FLAIR EDITION 1.2 TI VCT  703000.000000
# 9                                    Manual  641917.464789
# 10                     TITANIUM 1.5L DIESEL  789000.000000
# 11                     TITANIUM 1.5L PETROL  793000.000000
# 12                  TITANIUM 1.5L PETROL AT  575000.000000
# 13                        TREND 1.5L PETROL  606000.000000
# 14                        TREND+ 1.2 TI-VCT  619000.000000

# %%
sns.boxplot(x='price',y='transmission',data=h) # Automatic transmission cars tend to have a higher average price compared to Manual transmission cars in this dataset.
# Out:
# <Axes: xlabel='price', ylabel='transmission'>

# %%
#What is the average price for each car make and model?

# %%
u=df.groupby(['make', 'model'])['price'].mean().reset_index()
u
# Out:
#         make         model         price
# 0       FORD      ECOSPORT  6.994138e+05
# 1       FORD     FREESTYLE  5.435000e+05
# 2       Ford      ECOSPORT  5.600000e+05
# 3       Ford      Ecosport  6.696143e+05
# 4       Ford     FREESTYLE  6.330909e+05
# 5      HONDA         AMAZE  5.330000e+05
# 6      HONDA          CITY  7.266250e+05
# 7      HONDA          JAZZ  6.014545e+05
# 8    HYUNDAI     ELITE I20  5.588591e+05
# 9    HYUNDAI     GRAND I10  4.560250e+05
# 10   HYUNDAI    NEW SANTRO  5.147188e+05
# 11     Honda         AMAZE  5.262500e+05
# 12     Honda         Amaze  5.120519e+05
# 13     Honda          CITY  8.320000e+05
# 14     Honda          City  7.582391e+05
# 15     Honda          Jazz  5.600400e+05
# 16   Hyundai     ELITE I20  5.117500e+05
# 17   Hyundai     Elite i20  5.933258e+05
# 18   Hyundai     GRAND I10  4.660000e+05
# 19   Hyundai     Grand i10  4.609608e+05
# 20   Hyundai    NEW SANTRO  5.380390e+05
# 21       KIA        CARENS  1.672000e+06
# ...

# %%
sns.barplot(x='price', y='make', hue='model', data=u)
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
#What is the distribution of fuel types across different transmission categories?

# %%
sns.countplot(x='transmission', hue='fuel', data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
#Analyze the ownership distribution (owner) for cars in different states.

# %%
sns.countplot(x='state', hue='owner', data=df)
# Out:
# <Axes: xlabel='state', ylabel='count'>

# %%
sns.boxplot(x='fuel', y='price', hue='transmission', data=df, showfliers=True)
# Out:
# <Axes: xlabel='fuel', ylabel='price'>

# %%
p = df.groupby(['make', 'model', 'city'])['price'].mean().reset_index()
p
# Out:
#      make     model       city          price
# 0    FORD  ECOSPORT  Ahmedabad  889500.000000
# 1    FORD  ECOSPORT      Delhi  728833.333333
# 2    FORD  ECOSPORT  Ghaziabad  704142.857143
# 3    FORD  ECOSPORT    Gurgaon  728833.333333
# 4    FORD  ECOSPORT    Kolkata  576666.666667
# ..    ...       ...        ...            ...
# 266  Tata     Tiago    Gurgaon  542111.111111
# 267  Tata     Tiago      Kochi  519333.333333
# 268  Tata     Tiago    Kolkata  465000.000000
# 269  Tata     Tiago     Mumbai  589666.666667
# 270  Tata     Tiago      Noida  560750.000000
#
# [271 rows x 4 columns]

# %%
sns.barplot(x='make', y='price', hue='city', data=p)
# Out:
# <Axes: xlabel='make', ylabel='price'>

# %%
#Identify outliers in the price and kilometers columns using boxplots.

# %%
sns.boxplot(x='price',data=df)
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x='kilometers',data=df)
# Out:
# <Axes: xlabel='kilometers'>

# %% [markdown]
# Outliers in datasets, such as price and kilometers for cars, can arise due to various reasons. These reasons can be classified into data errors, natural variability, or even special cases that represent unique but legitimate data points.

# %%
#Which cities or states have the highest number of listed cars?

# %%
sns.barplot(x='state',y='city',data=df)
# Out:
# <Axes: xlabel='state', ylabel='city'>

# %%
#Visualize the average price of cars across different states.

# %%
v=df.groupby('state')['price'].mean().reset_index()
v
# Out:
#           state          price
# 0     CapitalUT  727089.552239
# 1       Gujarat  681575.539568
# 2       Haryana  735522.435897
# 3        Kerala  514639.285714
# 4   Maharashtra  618688.372093
# 5  UttarPradesh  724716.927900
# 6    WestBengal  534208.333333

# %%
sns.barplot(x='state', y='price', data=v)
# Out:
# <Axes: xlabel='state', ylabel='price'>

# %%
#Analyze the distribution of car listings by year. Are older cars more commonly sold?

# %%
year_counts = df['year'].value_counts().sort_index().reset_index()
year_counts
# Out:
#     year  count
# 0   2010      6
# 1   2011      6
# 2   2012     33
# 3   2013     31
# 4   2014     83
# 5   2015    133
# 6   2016    162
# 7   2017    184
# 8   2018    215
# 9   2019    291
# 10  2020    266
# 11  2021    337
# 12  2022     68

# %%
sns.barplot(x='year',y='count', data=year_counts)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
#How has the average price changed for different makes over the years?

# %%
xx=df.groupby(['make', 'year'])['price'].mean().reset_index()
xx
# Out:
#      make  year          price
# 0    FORD  2014  446000.000000
# 1    FORD  2015  437000.000000
# 2    FORD  2016  594500.000000
# 3    FORD  2017  708000.000000
# 4    FORD  2018  679833.333333
# ..    ...   ...            ...
# 104  Tata  2018  587826.086957
# 105  Tata  2019  803451.612903
# 106  Tata  2020  782676.923077
# 107  Tata  2021  901843.137255
# 108  Tata  2022  830727.272727
#
# [109 rows x 3 columns]

# %%
sns.barplot(x='year', y='price', hue='make', data=xx)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
#Create a new column for the car's age based on the year column and analyze its effect on the price.

# %%
y1=2025
df['age'] = y1 - df['year']

# %%
sns.lineplot(x='age', y='price', data=df, hue='make')
# Out:
# <Axes: xlabel='age', ylabel='price'>

# %%
cc = df['age'].corr(df['price']) # negative correlation typically observed in car pricing, where older cars are generally less expensive.
cc
# Out:
# -0.5740816539831609

# %%
df['pk']=df['price'] / df['kilometers']
df['pk']
# Out:
# 0        8.212334
# 1       10.033262
# 2       28.679154
# 3       35.608442
# 4        6.767546
#           ...
# 1810    29.457793
# 1811    19.489272
# 1812    24.902135
# 1813    40.656380
# 1814    13.623563
# Name: pk, Length: 1815, dtype: float64

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/total_cars.txt')
df['pk']=df['price'] / df['kilometers']

sns.lineplot(df['pk'])
# Out:
# <Axes: ylabel='pk'>

# %%
#Which factors most significantly influence the price of a used car?

# %% [markdown]
# Age of the Car,
# Brand and Model,
# Fuel Type,
# Transmission Type (Manual vs. Automatic),Service and Maintenance

# %%
#What are the best-selling makes and models in specific cities or states?

# %%
dd=df.groupby(['city', 'make', 'model']).size().reset_index(name='count')
dd
# Out:
#           city     make      model  count
# 0    Ahmedabad     FORD   ECOSPORT      2
# 1    Ahmedabad     Ford   Ecosport      3
# 2    Ahmedabad     Ford  FREESTYLE      1
# 3    Ahmedabad    HONDA      AMAZE      3
# 4    Ahmedabad    HONDA       CITY      5
# ..         ...      ...        ...    ...
# 266      Noida     Tata      NEXON     12
# 267      Noida     Tata      Tiago      8
# 268  ahmedabad  RENAULT      Kiger      1
# 269  ahmedabad  Renault       Kwid      1
# 270  ahmedabad  Renault     TRIBER      1
#
# [271 rows x 4 columns]

# %%
dd1 = dd.sort_values(['city','count'],ascending=[True,False])
dd1
# Out:
#           city     make      model  count
# 19   Ahmedabad   Maruti     Baleno     16
# 21   Ahmedabad   Maruti      Swift     16
# 13   Ahmedabad  Hyundai  Grand i10     13
# 10   Ahmedabad    Honda       City     10
# 7    Ahmedabad  HYUNDAI  GRAND I10      7
# ..         ...      ...        ...    ...
# 257      Noida  RENAULT      Kiger      1
# 258      Noida  RENAULT     TRIBER      1
# 268  ahmedabad  RENAULT      Kiger      1
# 269  ahmedabad  Renault       Kwid      1
# 270  ahmedabad  Renault     TRIBER      1
#
# [271 rows x 4 columns]

# %%
dd1.tail(10)
# Out:
#           city      make         model  count
# 92   Ghaziabad  Mahindra          Thar     17
# 239      Noida     Honda          City     17
# 137    Gurgaon    Maruti         Swift     18
# 253      Noida    Maruti        Baleno     18
# 53       Delhi    Maruti        Baleno     19
# 251      Noida    Maruti   New Wagon-R     20
# 93   Ghaziabad    Maruti   New Wagon-R     20
# 215     Mumbai    Maruti   New Wagon-R     20
# 51       Delhi    Maruti   New Wagon-R     20
# 135    Gurgaon    Maruti   New Wagon-R     20

# %%
#What recommendations would you provide to a used car dealer based on your analysis?

# %% [markdown]
# I would suggest the most happening car i.e., Maruti New Wagon-R, as many people are using it in most of the cities and it is affordable and also high in demand.
